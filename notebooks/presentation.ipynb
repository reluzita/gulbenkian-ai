# %%
import pandas as pd
import matplotlib.pyplot as plt
import re
import seaborn as sns

# %%
review_df = pd.read_pickle('C:\\Users\\ineso\\FEUP-3ano\\gulbenkian-ai\\data\\vegas-restaurants\\vegas_review_reduced.pickle')

# %%
business_df = pd.read_pickle('C:\\Users\\ineso\\FEUP-3ano\\gulbenkian-ai\\data\\vegas-restaurants\\restaurant_in_vegas.pickle')

# %%
user_df = pd.read_pickle('C:\\Users\\ineso\\FEUP-3ano\\gulbenkian-ai\\data\\vegas-restaurants\\vegas_users.pickle')

# %%
business_df = business_df[['business_id', 'stars', 'categories']]

# %%
user_df.shape
# Out:
# (536321, 22)

# %%
user_rev_count = review_df.user_id.value_counts()

# %%
user_rev_count.sort_values()
# Out:
# _I2wX2Ln6UgkaT6sNpFJKw       1
# fMfWFfDe7ezgdmyJtFiIcA       1
# T0pfc6dpSuHjnCD_vxulCw       1
# TVmX810ILlEp5Gw8pW1bJw       1
# rSOw6zF3S13f5sdUWfofBA       1
#                           ...
# n86B7IkbU20AkxlFX_5aew     645
# UYcmGbelzRa0Q6JqzLoguw     729
# U4INQZOPSUaj8hMjLlZ3KA     962
# PKEzKWv_FktMm2mGPjwd0Q    1063
# bLbSNkLggFnqwNNzzq-Ijw    1502
# Name: user_id, Length: 536321, dtype: int64

# %%
review_df.loc[review_df['user_id'] == 'bLbSNkLggFnqwNNzzq-Ijw']
# Out:
#                         user_id             business_id  stars
# 8473     bLbSNkLggFnqwNNzzq-Ijw  vtBtIV_23V95SwIDvj_OyA      4
# 12673    bLbSNkLggFnqwNNzzq-Ijw  wIz5nWZ-0LfgAq5N2Nu1dg      2
# 14860    bLbSNkLggFnqwNNzzq-Ijw  5TeA1dyLR7MIor-DfIrYog      3
# 20610    bLbSNkLggFnqwNNzzq-Ijw  -CbDQXiuKzPQ0_jiUz03aw      4
# 35442    bLbSNkLggFnqwNNzzq-Ijw  v0byOL8VL6v6muGa1anxFA      4
# ...                         ...                     ...    ...
# 8014785  bLbSNkLggFnqwNNzzq-Ijw  slUn4AINGy3QmDK62YGzoA      5
# 8015541  bLbSNkLggFnqwNNzzq-Ijw  O7ot_LMlCfLpOP9tBqeNfw      4
# 8018376  bLbSNkLggFnqwNNzzq-Ijw  h8mj8eJs-i3dGDuUlYrLLQ      4
# 8018856  bLbSNkLggFnqwNNzzq-Ijw  We16v_WgJei5cedG50OLTQ      4
# 8020987  bLbSNkLggFnqwNNzzq-Ijw  jX23x5u_sYz8q2u0SMDwPA      4
#
# [1502 rows x 3 columns]

# %%
value_counts = user_rev_count.value_counts()

# %%
value_counts.value_counts()
# Out:
# 1      77
# 2      47
# 3      16
# 4       8
# 12      7
#        ..
# 149     1
# 150     1
# 175     1
# 179     1
# 70      1
# Name: user_id, Length: 85, dtype: int64

# %%
value_counts.add({})
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda2\envs\py36\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index_class_helper.pxi in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: False
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-25-d85d8e22417b> in <module>
# ----> 1 only_one = value_counts.loc[value_counts[1]==1]
#
# ~\Anaconda2\envs\py36\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
# ...

# %%
ax = user_rev_count.value_counts().plot.pie()

# %%
user_rev_count.value_counts()
# Out:
# 1      323301
# 2       88036
# 3       40467
# 4       22636
# 5       14229
#         ...
# 208         1
# 207         1
# 204         1
# 202         1
# 645         1
# Name: user_id, Length: 276, dtype: int64

# %%
cat_temp1 = ';'.join(business_df['categories'])
cat_temp2 = re.split(';|,', cat_temp1)
bus_cat_trim = [item.lstrip() for item in cat_temp2]
df_bus_cat = pd.DataFrame(bus_cat_trim,columns=['category'])

# %%
stars_count = business_df.stars.value_counts()
bus_cat_count = bus_cat_count.sort_values()

# plot
fig = plt.figure(figsize=(10, 6))
ax = sns.barplot(bus_cat_count.index, bus_cat_count.values)
plt.title("Restaurants",fontsize = 20)
x_locs,x_labels = plt.xticks()
plt.setp(x_labels, rotation = 60)
plt.ylabel('Number of Businesses', fontsize = 12)
plt.xlabel('Category', fontsize = 12)

#text labels
r = ax.patches
labels = bus_cat_count.values
for rect, label in zip(r, labels):
    height = rect.get_height()
    ax.text(rect.get_x() + rect.get_width()/2, height + 10, label, ha='center', va='bottom')

# %%
business_df['city_state'] = business_df['city'] + ',' + business_df['state']
# Out:
# ipykernel_launcher:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
city_res_count = business_df.city_state.value_counts()
city_res_count = city_res_count.sort_values(ascending = False)
city_res_count = city_res_count.iloc[0:10]

# plot
fig = plt.figure(figsize=(10, 6))
ax = sns.barplot(city_res_count.index, city_res_count.values)
plt.title("Top Cities",fontsize = 20)
x_locs,x_labels = plt.xticks()
plt.setp(x_labels, rotation = 60)
plt.ylabel('Number of Businesses', fontsize = 12)
plt.xlabel('City,State', fontsize = 12)

#text labels
r = ax.patches
labels = city_res_count.values
for rect, label in zip(r, labels):
    height = rect.get_height()
    ax.text(rect.get_x() + rect.get_width()/2, height + 10, label, ha='center', va='bottom')

# %%
user_rev_count = review_df.user_id.value_counts()

# %%
user_rev_count

# %%
fig = plt.figure()
ax = sns.lineplot(user_rev_count.index, user_rev_count.values)
plt.title("Reviews p/ user",fontsize = 20)
x_locs,x_labels = plt.xticks()
plt.setp(x_labels, rotation = 60)
plt.ylabel('Number of User', fontsize = 12)
plt.xlabel('Number of reviews', fontsize = 12)
